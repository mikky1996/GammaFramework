# %%
# %matplotlib inline
import sys
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append('../infra/')

from AssetsData import AssetsData
from VizualExperiment import VizualExperiment
import FactorGenerator

# %%
df = pd.read_csv("../data/processed_rolling_data.csv").set_index(['TIMESTAMP', 'ID'])

# %%
viz = VizualExperiment()
'''
# This loop will plot historgam and nirmal distribution
for name in AssetsData().get_assets_names(df):
    viz.hist_asset_returns(name, df)
'''
viz.hist_asset_returns('S0005', df)

# %% [markdown]
# Those stocks really love to return to the origin, since all the densities functions look like the one above
#
# Probably we should consider to include boelinger bands feature or something
