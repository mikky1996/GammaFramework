# %%
# Magic
# %matplotlib inline

# Libraries in use
import os
import sys
import math
import pylab as pl
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
from sklearn import linear_model, neural_network, metrics
from matplotlib import collections  as mc

from myutil import *
import pickle

# %%
with open('assetslist_lasso_trim_10_300.pckl') as f:
    assetslist = pickle.load(f)

# %%
sum_nones = 0

# %%
scores = []

# %%
for i in assetslist.keys():
    if not assetslist[i].score:
        sum_nones += 1
    else:
        scores.append(assetslist[i].score)

# %%
sorted(scores)[len(scores)/2]
#median
# Out:
# 0.034430894868164308

# %%
sum_nones
# number of assets that do not have any model
# Out:
# 210

# %%
sorted(scores)
# Out:
# [0.01223735252565572,
#  0.01270063250379494,
#  0.013045125544039804,
#  0.014415865699851649,
#  0.014604390666671407,
#  0.014606710159988044,
#  0.014625749562317212,
#  0.015135357172736619,
#  0.01514169211589611,
#  0.015224899737015908,
#  0.015302716007190355,
#  0.015334135824008666,
#  0.015821904685215049,
#  0.015975054600242178,
#  0.016151181626798961,
#  0.016464113046931184,
#  0.016635693351033654,
#  0.01705277698000407,
#  0.01733900202632277,
#  0.017390997041762057,
#  0.017509097453732303,
#  0.017522071018311491,
#  0.017601027792116253,
#  0.017648852638687207,
#  0.017787490434145514,
#  0.017978132511839107,
#  0.018181935491770052,
#  0.018230118866575884,
#  0.018271861128386191,
#  0.018308653159695654,
#  0.018309669683092444,
#  0.018374436066068922,
#  0.018395690742370241,
#  0.018496355606823278,
#  0.018533569652144144,
#  0.018660734264189238,
#  0.018742193754539005,
#  0.018753089532633771,
#  0.018755532672926845,
#  0.018765440712834036,
# ...
